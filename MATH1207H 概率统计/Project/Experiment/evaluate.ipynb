# %%
import torch
from torch import nn, optim
from torch.autograd import grad


def generate(n=10000, s=1, t=1, k=1):
    x_value = s * torch.randn(n, 1)
    y_value = k * x_value + s * torch.randn(n, 1)
    x_prime = y_value + t * torch.randn(n, 1)
    return torch.cat([x_value, x_prime], dim=1), y_value


def evaluate(loss, omega):
    g1 = grad(loss[0::2].mean(), omega, create_graph=True)[0]
    g2 = grad(loss[1::2].mean(), omega, create_graph=True)[0]
    return (g1 * g2).sum()


ks = [0.3, 0.5, 0.7, 0.8, 0.9, 1.0, 1.5, 2.0, 2.5, 3.0]


for k in ks:
    print("\n---------- k = {} ----------".format(k))
    sample = [generate(s=1.0, k=k), generate(s=0.1, k=k)]

    theta = nn.Parameter(torch.ones(2, 1))
    omega = nn.Parameter(torch.Tensor([1.0]))
    optimizer = optim.SGD([theta], lr=1e-3)
    function = nn.MSELoss(reduction='none')
    record = []

    for epoch in range(1, 100001):
        error = 0
        penalty = 0
        for x, y in sample:
            p = torch.randperm(len(x))
            x, y = x[p], y[p]
            loss = function(x @ theta * omega, y)
            error += loss.mean()
            penalty += evaluate(loss, omega)
        optimizer.zero_grad()
        (1e-5 * error + penalty).backward()
        optimizer.step()
        record.append((1e-5 * error + penalty).item())
        if epoch % 5000 == 0:
            print('----- Epoch {} -----'.format(epoch))
            print('Error: {}'.format(error.item()))
            print('Penalty: {}'.format(penalty.item()))
            print(theta)
# Out:
# ---------- k = 0.3 ----------
# ----- Epoch 5000 -----
# Error: 0.8703827261924744
# Penalty: 0.00016503059305250645
# Parameter containing:
# tensor([[0.4294],
#         [0.0872]], requires_grad=True)
# ----- Epoch 10000 -----
# Error: 0.891944944858551
# Penalty: 8.399621583521366e-05
# Parameter containing:
# tensor([[0.4126],
#         [0.0688]], requires_grad=True)
# ----- Epoch 15000 -----
# Error: 0.9027113318443298
# Penalty: 4.743588579003699e-05
# Parameter containing:
# tensor([[0.4034],
#         [0.0602]], requires_grad=True)
# ----- Epoch 20000 -----
# Error: 0.9095416069030762
# Penalty: -0.00010865063813980669
# Parameter containing:
# tensor([[0.3973],
#         [0.0549]], requires_grad=True)
# ----- Epoch 25000 -----
# Error: 0.9143661260604858
# Penalty: -4.827185330213979e-05
# Parameter containing:
# tensor([[0.3928],
#         [0.0513]], requires_grad=True)
# ----- Epoch 30000 -----
# Error: 0.9180030822753906
# Penalty: -4.301983426557854e-05
# Parameter containing:
# tensor([[0.3894],
#         [0.0486]], requires_grad=True)
# ----- Epoch 35000 -----
# Error: 0.9208997488021851
# Penalty: -0.00032246665796265006
# Parameter containing:
# tensor([[0.3866],
#         [0.0465]], requires_grad=True)
# ----- Epoch 40000 -----
# Error: 0.9232514500617981
# Penalty: 1.2686689842666965e-05
# Parameter containing:
# tensor([[0.3843],
#         [0.0448]], requires_grad=True)
# ----- Epoch 45000 -----
# Error: 0.9251868724822998
# Penalty: 8.435034033027478e-06
# Parameter containing:
# tensor([[0.3824],
#         [0.0434]], requires_grad=True)
# ----- Epoch 50000 -----
# Error: 0.9267919659614563
# Penalty: 1.0089477655128576e-05
# Parameter containing:
# tensor([[0.3808],
#         [0.0422]], requires_grad=True)
# ----- Epoch 55000 -----
# Error: 0.9281975626945496
# Penalty: 7.668990292586386e-06
# Parameter containing:
# tensor([[0.3793],
#         [0.0413]], requires_grad=True)
# ----- Epoch 60000 -----
# Error: 0.9294288158416748
# Penalty: -2.376567863393575e-05
# Parameter containing:
# tensor([[0.3781],
#         [0.0404]], requires_grad=True)
# ----- Epoch 65000 -----
# Error: 0.9304986596107483
# Penalty: -1.5782956324983388e-05
# Parameter containing:
# tensor([[0.3770],
#         [0.0396]], requires_grad=True)
# ----- Epoch 70000 -----
# Error: 0.9314478039741516
# Penalty: -9.726129974296782e-06
# Parameter containing:
# tensor([[0.3760],
#         [0.0390]], requires_grad=True)
# ----- Epoch 75000 -----
# Error: 0.9322484731674194
# Penalty: -0.00012811798660550267
# Parameter containing:
# tensor([[0.3752],
#         [0.0384]], requires_grad=True)
# ----- Epoch 80000 -----
# Error: 0.9329406023025513
# Penalty: 6.851621947134845e-06
# Parameter containing:
# tensor([[0.3745],
#         [0.0379]], requires_grad=True)
# ----- Epoch 85000 -----
# Error: 0.9336146712303162
# Penalty: -0.00020795295131392777
# Parameter containing:
# tensor([[0.3738],
#         [0.0375]], requires_grad=True)
# ----- Epoch 90000 -----
# Error: 0.9342214465141296
# Penalty: -1.7171473700727802e-06
# Parameter containing:
# tensor([[0.3732],
#         [0.0370]], requires_grad=True)
# ----- Epoch 95000 -----
# Error: 0.9347447752952576
# Penalty: -0.0002730579290073365
# Parameter containing:
# tensor([[0.3726],
#         [0.0367]], requires_grad=True)
# ----- Epoch 100000 -----
# Error: 0.9352296590805054
# Penalty: 1.8052724044537172e-06
# Parameter containing:
# tensor([[0.3721],
#         [0.0364]], requires_grad=True)
#
# ---------- k = 0.5 ----------
# ----- Epoch 5000 -----
# Error: 0.8750544190406799
# Penalty: 0.00014730179100297391
# Parameter containing:
# tensor([[0.5764],
#         [0.0804]], requires_grad=True)
# ----- Epoch 10000 -----
# Error: 0.90268874168396
# Penalty: -0.00015853137301746756
# Parameter containing:
# tensor([[0.5660],
#         [0.0609]], requires_grad=True)
# ----- Epoch 15000 -----
# Error: 0.9157925844192505
# Penalty: 1.1139012713101692e-05
# Parameter containing:
# tensor([[0.5603],
#         [0.0522]], requires_grad=True)
# ----- Epoch 20000 -----
# Error: 0.9238561391830444
# Penalty: -0.00034424164914526045
# Parameter containing:
# tensor([[0.5565],
#         [0.0470]], requires_grad=True)
# ----- Epoch 25000 -----
# Error: 0.9294037222862244
# Penalty: -4.820425601792522e-05
# Parameter containing:
# tensor([[0.5538],
#         [0.0435]], requires_grad=True)
# ----- Epoch 30000 -----
# Error: 0.9333521723747253
# Penalty: -3.172721335431561e-06
# Parameter containing:
# tensor([[0.5518],
#         [0.0410]], requires_grad=True)
# ----- Epoch 35000 -----
# Error: 0.9363939762115479
# Penalty: -4.9816089813248254e-06
# Parameter containing:
# tensor([[0.5503],
#         [0.0392]], requires_grad=True)
# ----- Epoch 40000 -----
# Error: 0.9389545917510986
# Penalty: -3.374204970896244e-05
# Parameter containing:
# tensor([[0.5490],
#         [0.0376]], requires_grad=True)
# ----- Epoch 45000 -----
# Error: 0.9409439563751221
# Penalty: -7.671263301745057e-05
# Parameter containing:
# tensor([[0.5479],
#         [0.0364]], requires_grad=True)
# ----- Epoch 50000 -----
# Error: 0.9426017999649048
# Penalty: -0.00012244697427377105
# Parameter containing:
# tensor([[0.5471],
#         [0.0354]], requires_grad=True)
# ----- Epoch 55000 -----
# Error: 0.9439437985420227
# Penalty: -0.0004227828176226467
# Parameter containing:
# tensor([[0.5464],
#         [0.0346]], requires_grad=True)
# ----- Epoch 60000 -----
# Error: 0.9450811743736267
# Penalty: 4.130894467380131e-06
# Parameter containing:
# tensor([[0.5457],
#         [0.0339]], requires_grad=True)
# ----- Epoch 65000 -----
# Error: 0.9460382461547852
# Penalty: -0.0004032643628306687
# Parameter containing:
# tensor([[0.5453],
#         [0.0334]], requires_grad=True)
# ----- Epoch 70000 -----
# Error: 0.9466667175292969
# Penalty: -0.00011375157191650942
# Parameter containing:
# tensor([[0.5449],
#         [0.0330]], requires_grad=True)
# ----- Epoch 75000 -----
# Error: 0.9472178816795349
# Penalty: -7.388521771645173e-05
# Parameter containing:
# tensor([[0.5446],
#         [0.0327]], requires_grad=True)
# ----- Epoch 80000 -----
# Error: 0.9478151798248291
# Penalty: -5.855877316207625e-05
# Parameter containing:
# tensor([[0.5443],
#         [0.0323]], requires_grad=True)
# ----- Epoch 85000 -----
# Error: 0.948397159576416
# Penalty: -0.00024810031754896045
# Parameter containing:
# tensor([[0.5439],
#         [0.0320]], requires_grad=True)
# ----- Epoch 90000 -----
# Error: 0.9488497376441956
# Penalty: -2.918501922977157e-05
# Parameter containing:
# tensor([[0.5437],
#         [0.0317]], requires_grad=True)
# ----- Epoch 95000 -----
# Error: 0.9492089152336121
# Penalty: -0.00024675054010003805
# Parameter containing:
# tensor([[0.5435],
#         [0.0315]], requires_grad=True)
# ----- Epoch 100000 -----
# Error: 0.9494261145591736
# Penalty: -5.543452061829157e-06
# Parameter containing:
# tensor([[0.5434],
#         [0.0314]], requires_grad=True)
#
# ---------- k = 0.7 ----------
# ----- Epoch 5000 -----
# Error: 0.8945125341415405
# Penalty: 1.171728945337236e-05
# Parameter containing:
# tensor([[0.7272],
#         [0.0802]], requires_grad=True)
# ----- Epoch 10000 -----
# Error: 0.9278862476348877
# Penalty: -0.0001829496177379042
# Parameter containing:
# tensor([[0.7227],
#         [0.0580]], requires_grad=True)
# ----- Epoch 15000 -----
# Error: 0.9431275129318237
# Penalty: -0.00012155667354818434
# Parameter containing:
# tensor([[0.7197],
#         [0.0485]], requires_grad=True)
# ----- Epoch 20000 -----
# Error: 0.9520328640937805
# Penalty: 1.00915422081016e-05
# Parameter containing:
# tensor([[0.7177],
#         [0.0431]], requires_grad=True)
# ----- Epoch 25000 -----
# Error: 0.9580163955688477
# Penalty: -0.0003868568455800414
# Parameter containing:
# tensor([[0.7163],
#         [0.0396]], requires_grad=True)
# ----- Epoch 30000 -----
# Error: 0.9621332883834839
# Penalty: -2.7869627956533805e-06
# Parameter containing:
# tensor([[0.7153],
#         [0.0372]], requires_grad=True)
# ----- Epoch 35000 -----
# Error: 0.9652217626571655
# Penalty: -0.0015748102450743318
# Parameter containing:
# tensor([[0.7145],
#         [0.0354]], requires_grad=True)
# ----- Epoch 40000 -----
# Error: 0.9678511619567871
# Penalty: -0.0005896826041862369
# Parameter containing:
# tensor([[0.7138],
#         [0.0339]], requires_grad=True)
# ----- Epoch 45000 -----
# Error: 0.9696709513664246
# Penalty: -8.833445463096723e-06
# Parameter containing:
# tensor([[0.7133],
#         [0.0329]], requires_grad=True)
# ----- Epoch 50000 -----
# Error: 0.9711313247680664
# Penalty: -0.000149864936247468
# Parameter containing:
# tensor([[0.7129],
#         [0.0321]], requires_grad=True)
# ----- Epoch 55000 -----
# Error: 0.9722679853439331
# Penalty: 3.135571660095593e-07
# Parameter containing:
# tensor([[0.7126],
#         [0.0314]], requires_grad=True)
# ----- Epoch 60000 -----
# Error: 0.9731491804122925
# Penalty: -1.3854949429514818e-05
# Parameter containing:
# tensor([[0.7123],
#         [0.0309]], requires_grad=True)
# ----- Epoch 65000 -----
# Error: 0.9739270806312561
# Penalty: -0.0002335545141249895
# Parameter containing:
# tensor([[0.7121],
#         [0.0305]], requires_grad=True)
# ----- Epoch 70000 -----
# Error: 0.9746847152709961
# Penalty: -0.00031669263262301683
# Parameter containing:
# tensor([[0.7119],
#         [0.0301]], requires_grad=True)
# ----- Epoch 75000 -----
# Error: 0.9752160310745239
# Penalty: -0.00012299038644414395
# Parameter containing:
# tensor([[0.7118],
#         [0.0298]], requires_grad=True)
# ----- Epoch 80000 -----
# Error: 0.9757645726203918
# Penalty: -2.864555881387787e-07
# Parameter containing:
# tensor([[0.7116],
#         [0.0295]], requires_grad=True)
# ----- Epoch 85000 -----
# Error: 0.9764620065689087
# Penalty: -9.600522025721148e-05
# Parameter containing:
# tensor([[0.7114],
#         [0.0291]], requires_grad=True)
# ----- Epoch 90000 -----
# Error: 0.9766274094581604
# Penalty: -9.070846135728061e-05
# Parameter containing:
# tensor([[0.7113],
#         [0.0290]], requires_grad=True)
# ----- Epoch 95000 -----
# Error: 0.9770236015319824
# Penalty: -1.5104535123100504e-05
# Parameter containing:
# tensor([[0.7112],
#         [0.0288]], requires_grad=True)
# ----- Epoch 100000 -----
# Error: 0.9772871136665344
# Penalty: -0.00020351592684164643
# Parameter containing:
# tensor([[0.7112],
#         [0.0286]], requires_grad=True)
#
# ---------- k = 0.8 ----------
# ----- Epoch 5000 -----
# Error: 0.8826697468757629
# Penalty: 0.00018120696768164635
# Parameter containing:
# tensor([[0.8233],
#         [0.0859]], requires_grad=True)
# ----- Epoch 10000 -----
# Error: 0.9227864742279053
# Penalty: -0.0002732857537921518
# Parameter containing:
# tensor([[0.8247],
#         [0.0592]], requires_grad=True)
# ----- Epoch 15000 -----
# Error: 0.9405323266983032
# Penalty: -1.4970137272030115e-05
# Parameter containing:
# tensor([[0.8241],
#         [0.0483]], requires_grad=True)
# ----- Epoch 20000 -----
# Error: 0.9511206150054932
# Penalty: -4.625697329174727e-05
# Parameter containing:
# tensor([[0.8233],
#         [0.0420]], requires_grad=True)
# ----- Epoch 25000 -----
# Error: 0.957909345626831
# Penalty: -0.0005330954445526004
# Parameter containing:
# tensor([[0.8227],
#         [0.0381]], requires_grad=True)
# ----- Epoch 30000 -----
# Error: 0.9629130959510803
# Penalty: -2.1370566173573025e-05
# Parameter containing:
# tensor([[0.8223],
#         [0.0352]], requires_grad=True)
# ----- Epoch 35000 -----
# Error: 0.966778039932251
# Penalty: -1.9217557564843446e-05
# Parameter containing:
# tensor([[0.8218],
#         [0.0330]], requires_grad=True)
# ----- Epoch 40000 -----
# Error: 0.9694761037826538
# Penalty: -7.83036375651136e-06
# Parameter containing:
# tensor([[0.8215],
#         [0.0315]], requires_grad=True)
# ----- Epoch 45000 -----
# Error: 0.9717991948127747
# Penalty: -0.0001066448021447286
# Parameter containing:
# tensor([[0.8213],
#         [0.0302]], requires_grad=True)
# ----- Epoch 50000 -----
# Error: 0.9733970165252686
# Penalty: -3.740174179256428e-07
# Parameter containing:
# tensor([[0.8211],
#         [0.0293]], requires_grad=True)
# ----- Epoch 55000 -----
# Error: 0.9749768972396851
# Penalty: -0.0008436533971689641
# Parameter containing:
# tensor([[0.8209],
#         [0.0284]], requires_grad=True)
# ----- Epoch 60000 -----
# Error: 0.9760237336158752
# Penalty: -0.00019828221411444247
# Parameter containing:
# tensor([[0.8208],
#         [0.0278]], requires_grad=True)
# ----- Epoch 65000 -----
# Error: 0.9769665002822876
# Penalty: -0.0010135361226275563
# Parameter containing:
# tensor([[0.8206],
#         [0.0273]], requires_grad=True)
# ----- Epoch 70000 -----
# Error: 0.9779257774353027
# Penalty: -0.0005425698473118246
# Parameter containing:
# tensor([[0.8205],
#         [0.0268]], requires_grad=True)
# ----- Epoch 75000 -----
# Error: 0.9785619378089905
# Penalty: -0.00023287427029572427
# Parameter containing:
# tensor([[0.8204],
#         [0.0264]], requires_grad=True)
# ----- Epoch 80000 -----
# Error: 0.9792051315307617
# Penalty: -0.0008231592946685851
# Parameter containing:
# tensor([[0.8203],
#         [0.0261]], requires_grad=True)
# ----- Epoch 85000 -----
# Error: 0.9797647595405579
# Penalty: -1.2307727956795134e-05
# Parameter containing:
# tensor([[0.8203],
#         [0.0258]], requires_grad=True)
# ----- Epoch 90000 -----
# Error: 0.9801006317138672
# Penalty: -3.2371244742535055e-05
# Parameter containing:
# tensor([[0.8202],
#         [0.0256]], requires_grad=True)
# ----- Epoch 95000 -----
# Error: 0.9808056354522705
# Penalty: -1.8437587641528808e-05
# Parameter containing:
# tensor([[0.8201],
#         [0.0252]], requires_grad=True)
# ----- Epoch 100000 -----
# Error: 0.9810543656349182
# Penalty: -0.0008637678110972047
# Parameter containing:
# tensor([[0.8201],
#         [0.0251]], requires_grad=True)
#
# ---------- k = 0.9 ----------
# ----- Epoch 5000 -----
# Error: 0.8396232724189758
# Penalty: -0.0010389683302491903
# Parameter containing:
# tensor([[0.8953],
#         [0.0906]], requires_grad=True)
# ----- Epoch 10000 -----
# Error: 0.8816317915916443
# Penalty: 5.0041897338815033e-05
# Parameter containing:
# tensor([[0.9025],
#         [0.0615]], requires_grad=True)
# ----- Epoch 15000 -----
# Error: 0.9006933569908142
# Penalty: -9.98685572994873e-06
# Parameter containing:
# tensor([[0.9042],
#         [0.0494]], requires_grad=True)
# ----- Epoch 20000 -----
# Error: 0.9118661284446716
# Penalty: -0.0001336745626758784
# Parameter containing:
# tensor([[0.9048],
#         [0.0426]], requires_grad=True)
# ----- Epoch 25000 -----
# Error: 0.9194735288619995
# Penalty: -8.431806054431945e-05
# Parameter containing:
# tensor([[0.9051],
#         [0.0381]], requires_grad=True)
# ----- Epoch 30000 -----
# Error: 0.9248916506767273
# Penalty: -7.42380871088244e-05
# Parameter containing:
# tensor([[0.9052],
#         [0.0349]], requires_grad=True)
# ----- Epoch 35000 -----
# Error: 0.9288010597229004
# Penalty: -0.0002558626001700759
# Parameter containing:
# tensor([[0.9052],
#         [0.0326]], requires_grad=True)
# ----- Epoch 40000 -----
# Error: 0.9321198463439941
# Penalty: -0.0007870106492191553
# Parameter containing:
# tensor([[0.9052],
#         [0.0307]], requires_grad=True)
# ----- Epoch 45000 -----
# Error: 0.9349644184112549
# Penalty: -0.00028336065588518977
# Parameter containing:
# tensor([[0.9052],
#         [0.0291]], requires_grad=True)
# ----- Epoch 50000 -----
# Error: 0.9370769262313843
# Penalty: -9.197390318149701e-05
# Parameter containing:
# tensor([[0.9052],
#         [0.0279]], requires_grad=True)
# ----- Epoch 55000 -----
# Error: 0.9390485286712646
# Penalty: -0.0014491119654849172
# Parameter containing:
# tensor([[0.9052],
#         [0.0268]], requires_grad=True)
# ----- Epoch 60000 -----
# Error: 0.9407514929771423
# Penalty: -0.0002553292433731258
# Parameter containing:
# tensor([[0.9052],
#         [0.0258]], requires_grad=True)
# ----- Epoch 65000 -----
# Error: 0.9421462416648865
# Penalty: -8.83659886312671e-05
# Parameter containing:
# tensor([[0.9052],
#         [0.0250]], requires_grad=True)
# ----- Epoch 70000 -----
# Error: 0.9432990550994873
# Penalty: -5.58359488422866e-06
# Parameter containing:
# tensor([[0.9052],
#         [0.0244]], requires_grad=True)
# ----- Epoch 75000 -----
# Error: 0.9444316625595093
# Penalty: -3.7484525819309056e-05
# Parameter containing:
# tensor([[0.9051],
#         [0.0238]], requires_grad=True)
# ----- Epoch 80000 -----
# Error: 0.9454530477523804
# Penalty: -0.0002718011091928929
# Parameter containing:
# tensor([[0.9051],
#         [0.0232]], requires_grad=True)
# ----- Epoch 85000 -----
# Error: 0.9460282921791077
# Penalty: -0.00020552742353174835
# Parameter containing:
# tensor([[0.9051],
#         [0.0229]], requires_grad=True)
# ----- Epoch 90000 -----
# Error: 0.9471385478973389
# Penalty: -0.0006179777556098998
# Parameter containing:
# tensor([[0.9051],
#         [0.0223]], requires_grad=True)
# ----- Epoch 95000 -----
# Error: 0.947968602180481
# Penalty: -0.001211419585160911
# Parameter containing:
# tensor([[0.9050],
#         [0.0218]], requires_grad=True)
# ----- Epoch 100000 -----
# Error: 0.9486773610115051
# Penalty: -0.0008569502970203757
# Parameter containing:
# tensor([[0.9050],
#         [0.0214]], requires_grad=True)
#
# ---------- k = 1.0 ----------
# ----- Epoch 5000 -----
# Error: 0.8297042846679688
# Penalty: 0.00031136214965954423
# Parameter containing:
# tensor([[0.9682],
#         [0.0959]], requires_grad=True)
# ----- Epoch 10000 -----
# Error: 0.8755718469619751
# Penalty: 5.48622447240632e-05
# Parameter containing:
# tensor([[0.9817],
#         [0.0639]], requires_grad=True)
# ----- Epoch 15000 -----
# Error: 0.8971712589263916
# Penalty: 2.478945316397585e-05
# Parameter containing:
# tensor([[0.9860],
#         [0.0502]], requires_grad=True)
# ----- Epoch 20000 -----
# Error: 0.9098184704780579
# Penalty: -0.0011370166903361678
# Parameter containing:
# tensor([[0.9881],
#         [0.0425]], requires_grad=True)
# ----- Epoch 25000 -----
# Error: 0.9184414744377136
# Penalty: -3.657936031231657e-05
# Parameter containing:
# tensor([[0.9893],
#         [0.0374]], requires_grad=True)
# ----- Epoch 30000 -----
# Error: 0.9250400066375732
# Penalty: -0.00025788292987272143
# Parameter containing:
# tensor([[0.9901],
#         [0.0336]], requires_grad=True)
# ----- Epoch 35000 -----
# Error: 0.9306923747062683
# Penalty: -1.8170419934904203e-05
# Parameter containing:
# tensor([[0.9907],
#         [0.0303]], requires_grad=True)
# ----- Epoch 40000 -----
# Error: 0.9348095655441284
# Penalty: -0.0006309158052317798
# Parameter containing:
# tensor([[0.9911],
#         [0.0280]], requires_grad=True)
# ----- Epoch 45000 -----
# Error: 0.9378880262374878
# Penalty: -0.0010713323717936873
# Parameter containing:
# tensor([[0.9914],
#         [0.0263]], requires_grad=True)
# ----- Epoch 50000 -----
# Error: 0.941024124622345
# Penalty: -0.0003853633825201541
# Parameter containing:
# tensor([[0.9917],
#         [0.0245]], requires_grad=True)
# ----- Epoch 55000 -----
# Error: 0.9437956809997559
# Penalty: -0.0003709610609803349
# Parameter containing:
# tensor([[0.9919],
#         [0.0230]], requires_grad=True)
# ----- Epoch 60000 -----
# Error: 0.9459095001220703
# Penalty: -4.526723841991043e-06
# Parameter containing:
# tensor([[0.9921],
#         [0.0218]], requires_grad=True)
# ----- Epoch 65000 -----
# Error: 0.9479951858520508
# Penalty: -1.029313716571778e-05
# Parameter containing:
# tensor([[0.9922],
#         [0.0207]], requires_grad=True)
# ----- Epoch 70000 -----
# Error: 0.9496945738792419
# Penalty: -0.00013126152043696493
# Parameter containing:
# tensor([[0.9923],
#         [0.0197]], requires_grad=True)
# ----- Epoch 75000 -----
# Error: 0.9514920711517334
# Penalty: -0.00016734088421799242
# Parameter containing:
# tensor([[0.9925],
#         [0.0188]], requires_grad=True)
# ----- Epoch 80000 -----
# Error: 0.953063428401947
# Penalty: -0.000301374209811911
# Parameter containing:
# tensor([[0.9926],
#         [0.0179]], requires_grad=True)
# ----- Epoch 85000 -----
# Error: 0.9541418552398682
# Penalty: -0.0003122632042504847
# Parameter containing:
# tensor([[0.9927],
#         [0.0173]], requires_grad=True)
# ----- Epoch 90000 -----
# Error: 0.9553719758987427
# Penalty: -0.0006401299615390599
# Parameter containing:
# tensor([[0.9927],
#         [0.0167]], requires_grad=True)
# ----- Epoch 95000 -----
# Error: 0.9562132954597473
# Penalty: -6.09902708674781e-05
# Parameter containing:
# tensor([[0.9928],
#         [0.0162]], requires_grad=True)
# ----- Epoch 100000 -----
# Error: 0.9571946859359741
# Penalty: -0.0002945401065517217
# Parameter containing:
# tensor([[0.9928],
#         [0.0157]], requires_grad=True)
#
# ---------- k = 1.5 ----------
# ----- Epoch 5000 -----
# Error: 0.7922293543815613
# Penalty: -0.001277622184716165
# Parameter containing:
# tensor([[1.3636],
#         [0.1301]], requires_grad=True)
# ----- Epoch 10000 -----
# Error: 0.8496604561805725
# Penalty: -0.0015469894278794527
# Parameter containing:
# tensor([[1.4153],
#         [0.0853]], requires_grad=True)
# ----- Epoch 15000 -----
# Error: 0.8783617615699768
# Penalty: 6.103523628553376e-05
# Parameter containing:
# tensor([[1.4359],
#         [0.0658]], requires_grad=True)
# ----- Epoch 20000 -----
# Error: 0.8970171809196472
# Penalty: 3.8916870835237205e-05
# Parameter containing:
# tensor([[1.4480],
#         [0.0540]], requires_grad=True)
# ----- Epoch 25000 -----
# Error: 0.9105944633483887
# Penalty: -6.172759458422661e-05
# Parameter containing:
# tensor([[1.4561],
#         [0.0456]], requires_grad=True)
# ----- Epoch 30000 -----
# Error: 0.9212972521781921
# Penalty: -8.668721420690417e-05
# Parameter containing:
# tensor([[1.4622],
#         [0.0393]], requires_grad=True)
# ----- Epoch 35000 -----
# Error: 0.9303823709487915
# Penalty: -0.0002995600807480514
# Parameter containing:
# tensor([[1.4671],
#         [0.0340]], requires_grad=True)
# ----- Epoch 40000 -----
# Error: 0.9379826188087463
# Penalty: -0.0013383565237745643
# Parameter containing:
# tensor([[1.4712],
#         [0.0296]], requires_grad=True)
# ----- Epoch 45000 -----
# Error: 0.944890022277832
# Penalty: -0.0038595469668507576
# Parameter containing:
# tensor([[1.4748],
#         [0.0257]], requires_grad=True)
# ----- Epoch 50000 -----
# Error: 0.9511672854423523
# Penalty: -0.0013681250857189298
# Parameter containing:
# tensor([[1.4779],
#         [0.0223]], requires_grad=True)
# ----- Epoch 55000 -----
# Error: 0.957282543182373
# Penalty: -0.0004946753033436835
# Parameter containing:
# tensor([[1.4809],
#         [0.0189]], requires_grad=True)
# ----- Epoch 60000 -----
# Error: 0.9632447361946106
# Penalty: -0.00012977808364666998
# Parameter containing:
# tensor([[1.4837],
#         [0.0157]], requires_grad=True)
# ----- Epoch 65000 -----
# Error: 0.968498170375824
# Penalty: -0.0001264083111891523
# Parameter containing:
# tensor([[1.4862],
#         [0.0128]], requires_grad=True)
# ----- Epoch 70000 -----
# Error: 0.9740428328514099
# Penalty: -0.0003352195199113339
# Parameter containing:
# tensor([[1.4887],
#         [0.0099]], requires_grad=True)
# ----- Epoch 75000 -----
# Error: 0.9797407388687134
# Penalty: -0.0002945130108855665
# Parameter containing:
# tensor([[1.4913],
#         [0.0069]], requires_grad=True)
# ----- Epoch 80000 -----
# Error: 0.9852479100227356
# Penalty: -0.00011842130334116518
# Parameter containing:
# tensor([[1.4937],
#         [0.0040]], requires_grad=True)
# ----- Epoch 85000 -----
# Error: 0.9905521273612976
# Penalty: -0.0005467979935929179
# Parameter containing:
# tensor([[1.4960e+00],
#         [1.3003e-03]], requires_grad=True)
# ----- Epoch 90000 -----
# Error: 0.9957340955734253
# Penalty: -0.00025729264598339796
# Parameter containing:
# tensor([[ 1.4982e+00],
#         [-1.3390e-03]], requires_grad=True)
# ----- Epoch 95000 -----
# Error: 1.0008496046066284
# Penalty: -2.8436872526071966e-05
# Parameter containing:
# tensor([[ 1.5003],
#         [-0.0039]], requires_grad=True)
# ----- Epoch 100000 -----
# Error: 1.0061291456222534
# Penalty: -0.0008013449260033667
# Parameter containing:
# tensor([[ 1.5024],
#         [-0.0066]], requires_grad=True)
#
# ---------- k = 2.0 ----------
# ----- Epoch 5000 -----
# Error: 0.7616365551948547
# Penalty: 0.0033063306473195553
# Parameter containing:
# tensor([[1.7042],
#         [0.1702]], requires_grad=True)
# ----- Epoch 10000 -----
# Error: 0.8240504264831543
# Penalty: -0.0003963096532970667
# Parameter containing:
# tensor([[1.8016],
#         [0.1158]], requires_grad=True)
# ----- Epoch 15000 -----
# Error: 0.8582372665405273
# Penalty: 0.00026810402050614357
# Parameter containing:
# tensor([[1.8437],
#         [0.0910]], requires_grad=True)
# ----- Epoch 20000 -----
# Error: 0.8805161118507385
# Penalty: 0.0001184540378744714
# Parameter containing:
# tensor([[1.8684],
#         [0.0762]], requires_grad=True)
# ----- Epoch 25000 -----
# Error: 0.8969104886054993
# Penalty: -0.0014908482553437352
# Parameter containing:
# tensor([[1.8853],
#         [0.0658]], requires_grad=True)
# ----- Epoch 30000 -----
# Error: 0.9099894762039185
# Penalty: -0.0005346957477740943
# Parameter containing:
# tensor([[1.8982],
#         [0.0579]], requires_grad=True)
# ----- Epoch 35000 -----
# Error: 0.9214270114898682
# Penalty: 7.035603630356491e-06
# Parameter containing:
# tensor([[1.9091],
#         [0.0511]], requires_grad=True)
# ----- Epoch 40000 -----
# Error: 0.9312319755554199
# Penalty: 8.768108273216058e-06
# Parameter containing:
# tensor([[1.9180],
#         [0.0454]], requires_grad=True)
# ----- Epoch 45000 -----
# Error: 0.9398780465126038
# Penalty: -0.0005140894209034741
# Parameter containing:
# tensor([[1.9258],
#         [0.0404]], requires_grad=True)
# ----- Epoch 50000 -----
# Error: 0.9479297399520874
# Penalty: -4.7984489356167614e-05
# Parameter containing:
# tensor([[1.9328],
#         [0.0359]], requires_grad=True)
# ----- Epoch 55000 -----
# Error: 0.9553337693214417
# Penalty: -2.5921137421391904e-05
# Parameter containing:
# tensor([[1.9393],
#         [0.0319]], requires_grad=True)
# ----- Epoch 60000 -----
# Error: 0.9628497362136841
# Penalty: -0.002619469305500388
# Parameter containing:
# tensor([[1.9455],
#         [0.0278]], requires_grad=True)
# ----- Epoch 65000 -----
# Error: 0.9701326489448547
# Penalty: -0.005824734922498465
# Parameter containing:
# tensor([[1.9515],
#         [0.0238]], requires_grad=True)
# ----- Epoch 70000 -----
# Error: 0.9768502116203308
# Penalty: -0.0003709366428665817
# Parameter containing:
# tensor([[1.9569],
#         [0.0203]], requires_grad=True)
# ----- Epoch 75000 -----
# Error: 0.9838384985923767
# Penalty: -0.002477751113474369
# Parameter containing:
# tensor([[1.9625],
#         [0.0167]], requires_grad=True)
# ----- Epoch 80000 -----
# Error: 0.9907429218292236
# Penalty: -0.0029694978147745132
# Parameter containing:
# tensor([[1.9678],
#         [0.0131]], requires_grad=True)
# ----- Epoch 85000 -----
# Error: 0.9982877373695374
# Penalty: -0.0006077208672650158
# Parameter containing:
# tensor([[1.9735],
#         [0.0093]], requires_grad=True)
# ----- Epoch 90000 -----
# Error: 1.0054495334625244
# Penalty: -0.001319124479778111
# Parameter containing:
# tensor([[1.9790],
#         [0.0056]], requires_grad=True)
# ----- Epoch 95000 -----
# Error: 1.0129727125167847
# Penalty: -0.0009245972032658756
# Parameter containing:
# tensor([[1.9845e+00],
#         [1.8906e-03]], requires_grad=True)
# ----- Epoch 100000 -----
# Error: 1.0208115577697754
# Penalty: -0.0021623382344841957
# Parameter containing:
# tensor([[ 1.9902e+00],
#         [-1.9645e-03]], requires_grad=True)
#
# ---------- k = 2.5 ----------
# ----- Epoch 5000 -----
# Error: 0.7289236783981323
# Penalty: 0.0075770472176373005
# Parameter containing:
# tensor([[2.0064],
#         [0.2123]], requires_grad=True)
# ----- Epoch 10000 -----
# Error: 0.7892590165138245
# Penalty: 0.0017215264961123466
# Parameter containing:
# tensor([[2.1599],
#         [0.1481]], requires_grad=True)
# ----- Epoch 15000 -----
# Error: 0.8253251910209656
# Penalty: -0.002627409528940916
# Parameter containing:
# tensor([[2.2285],
#         [0.1184]], requires_grad=True)
# ----- Epoch 20000 -----
# Error: 0.850104033946991
# Penalty: -0.014626499265432358
# Parameter containing:
# tensor([[2.2700],
#         [0.1002]], requires_grad=True)
# ----- Epoch 25000 -----
# Error: 0.8688262104988098
# Penalty: -0.0007302447338588536
# Parameter containing:
# tensor([[2.2989],
#         [0.0873]], requires_grad=True)
# ----- Epoch 30000 -----
# Error: 0.8838518857955933
# Penalty: -7.514248136430979e-05
# Parameter containing:
# tensor([[2.3209],
#         [0.0774]], requires_grad=True)
# ----- Epoch 35000 -----
# Error: 0.8965663313865662
# Penalty: -0.005863081198185682
# Parameter containing:
# tensor([[2.3387],
#         [0.0693]], requires_grad=True)
# ----- Epoch 40000 -----
# Error: 0.9072652459144592
# Penalty: -0.00011976425594184548
# Parameter containing:
# tensor([[2.3535],
#         [0.0627]], requires_grad=True)
# ----- Epoch 45000 -----
# Error: 0.917271614074707
# Penalty: -0.0002281956112710759
# Parameter containing:
# tensor([[2.3663],
#         [0.0568]], requires_grad=True)
# ----- Epoch 50000 -----
# Error: 0.9256012439727783
# Penalty: -0.0002529866760596633
# Parameter containing:
# tensor([[2.3773],
#         [0.0518]], requires_grad=True)
# ----- Epoch 55000 -----
# Error: 0.9336209893226624
# Penalty: -8.346531831193715e-05
# Parameter containing:
# tensor([[2.3874],
#         [0.0472]], requires_grad=True)
# ----- Epoch 60000 -----
# Error: 0.9412601590156555
# Penalty: -0.003264657687395811
# Parameter containing:
# tensor([[2.3969],
#         [0.0428]], requires_grad=True)
# ----- Epoch 65000 -----
# Error: 0.9485586285591125
# Penalty: -0.0003033431130461395
# Parameter containing:
# tensor([[2.4057],
#         [0.0387]], requires_grad=True)
# ----- Epoch 70000 -----
# Error: 0.9553715586662292
# Penalty: -7.772430308250478e-07
# Parameter containing:
# tensor([[2.4139],
#         [0.0349]], requires_grad=True)
# ----- Epoch 75000 -----
# Error: 0.9624715447425842
# Penalty: -0.00042581421439535916
# Parameter containing:
# tensor([[2.4223],
#         [0.0310]], requires_grad=True)
# ----- Epoch 80000 -----
# Error: 0.969607412815094
# Penalty: -0.001740561448968947
# Parameter containing:
# tensor([[2.4304],
#         [0.0272]], requires_grad=True)
# ----- Epoch 85000 -----
# Error: 0.9766787886619568
# Penalty: -0.000829203228931874
# Parameter containing:
# tensor([[2.4385],
#         [0.0234]], requires_grad=True)
# ----- Epoch 90000 -----
# Error: 0.98345947265625
# Penalty: -2.7551537641556934e-05
# Parameter containing:
# tensor([[2.4461],
#         [0.0198]], requires_grad=True)
# ----- Epoch 95000 -----
# Error: 0.9902315735816956
# Penalty: -0.00034351146314293146
# Parameter containing:
# tensor([[2.4536],
#         [0.0163]], requires_grad=True)
# ----- Epoch 100000 -----
# Error: 0.9971625208854675
# Penalty: -0.0008912317571230233
# Parameter containing:
# tensor([[2.4614],
#         [0.0126]], requires_grad=True)
#
# ---------- k = 3.0 ----------
# ----- Epoch 5000 -----
# Error: 0.7064924836158752
# Penalty: 0.009587441571056843
# Parameter containing:
# tensor([[2.3223],
#         [0.2432]], requires_grad=True)
# ----- Epoch 10000 -----
# Error: 0.7634045481681824
# Penalty: -0.0029774128925055265
# Parameter containing:
# tensor([[2.5368],
#         [0.1706]], requires_grad=True)
# ----- Epoch 15000 -----
# Error: 0.800987958908081
# Penalty: -0.005797151941806078
# Parameter containing:
# tensor([[2.6349],
#         [0.1364]], requires_grad=True)
# ----- Epoch 20000 -----
# Error: 0.8276177644729614
# Penalty: -0.00012452650116756558
# Parameter containing:
# tensor([[2.6945],
#         [0.1155]], requires_grad=True)
# ----- Epoch 25000 -----
# Error: 0.8479260802268982
# Penalty: -2.6708177756518126e-05
# Parameter containing:
# tensor([[2.7360],
#         [0.1007]], requires_grad=True)
# ----- Epoch 30000 -----
# Error: 0.8642141819000244
# Penalty: -0.0017691650427877903
# Parameter containing:
# tensor([[2.7672],
#         [0.0895]], requires_grad=True)
# ----- Epoch 35000 -----
# Error: 0.8780677318572998
# Penalty: -0.001463647116906941
# Parameter containing:
# tensor([[2.7926],
#         [0.0804]], requires_grad=True)
# ----- Epoch 40000 -----
# Error: 0.8897179365158081
# Penalty: -0.009316145442426205
# Parameter containing:
# tensor([[2.8132],
#         [0.0729]], requires_grad=True)
# ----- Epoch 45000 -----
# Error: 0.9001078009605408
# Penalty: -0.0007257191464304924
# Parameter containing:
# tensor([[2.8311],
#         [0.0664]], requires_grad=True)
# ----- Epoch 50000 -----
# Error: 0.9096919894218445
# Penalty: -4.389811510918662e-05
# Parameter containing:
# tensor([[2.8470],
#         [0.0606]], requires_grad=True)
# ----- Epoch 55000 -----
# Error: 0.9190349578857422
# Penalty: -0.007499720435589552
# Parameter containing:
# tensor([[2.8622],
#         [0.0551]], requires_grad=True)
# ----- Epoch 60000 -----
# Error: 0.92738276720047
# Penalty: -0.006703343708068132
# Parameter containing:
# tensor([[2.8757],
#         [0.0501]], requires_grad=True)
# ----- Epoch 65000 -----
# Error: 0.9354822635650635
# Penalty: -0.0010685485322028399
# Parameter containing:
# tensor([[2.8883],
#         [0.0455]], requires_grad=True)
# ----- Epoch 70000 -----
# Error: 0.9431392550468445
# Penalty: -0.00011295906733721495
# Parameter containing:
# tensor([[2.9000],
#         [0.0412]], requires_grad=True)
# ----- Epoch 75000 -----
# Error: 0.9507018327713013
# Penalty: -0.00031612341990694404
# Parameter containing:
# tensor([[2.9113],
#         [0.0370]], requires_grad=True)
# ----- Epoch 80000 -----
# Error: 0.957951545715332
# Penalty: -0.0008404810796491802
# Parameter containing:
# tensor([[2.9222],
#         [0.0330]], requires_grad=True)
# ----- Epoch 85000 -----
# Error: 0.9653229713439941
# Penalty: -5.7009488955372944e-05
# Parameter containing:
# tensor([[2.9329],
#         [0.0290]], requires_grad=True)
# ----- Epoch 90000 -----
# Error: 0.9720944166183472
# Penalty: -0.02285054884850979
# Parameter containing:
# tensor([[2.9427],
#         [0.0254]], requires_grad=True)
# ----- Epoch 95000 -----
# Error: 0.9791659712791443
# Penalty: -0.00011163338785991073
# Parameter containing:
# tensor([[2.9526],
#         [0.0217]], requires_grad=True)
# ----- Epoch 100000 -----
# Error: 0.9859713912010193
# Penalty: -0.0011869616573676467
# Parameter containing:
# tensor([[2.9624],
#         [0.0181]], requires_grad=True)
